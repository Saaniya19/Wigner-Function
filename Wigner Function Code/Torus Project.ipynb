# %%
#make program interactive
# %matplotlib notebook

#import libraries
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
from random import randint

fig = plt.figure(facecolor="Black")
ax = plt.axes(projection="3d")
plt.axis("off")
plt.rcParams['figure.figsize'] = (6, 6)
#make segments into user input also?
segments = 10
anglesList = []
r, R = 1.0, 2.0
colours = ['Reds', 'Blues', 'Greens', 'Purples', 'Oranges']

matrixSize = input()
matrixSize = int(matrixSize)

for i in range (0, matrixSize):
    lowerAngle = i*(2*np.pi/matrixSize)
    upperAngle = (i+1)*(2*np.pi/matrixSize)
    anglesList.append(np.linspace(lowerAngle, upperAngle, segments))
    
ax.set_zlim3d(-3, 3)
ax.set_ylim3d(-3, 3)
ax.set_xlim3d(-3, 3)
    
for j in range (0, matrixSize):
    for k in range (0, matrixSize):
        theta, phi = np.meshgrid(anglesList[j], anglesList[k])
        X = (R + r*np.cos(phi))*np.cos(theta)
        Y = (R + r*np.cos(phi))*np.sin(theta)
        Z = r*np.sin(phi)
        ax.plot_surface(X, Y, Z, rstride = 1, cstride =1, cmap = colours[randint(0, 4)])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
# 10

# %%
#supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 
#'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 
#'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 
#'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 
#'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 
#'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 
#'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 
#'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 
#'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 
#'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 
#'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 
#'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 
#'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 
#'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 
#'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 
#'viridis_r', 'winter', 'winter_r'

# %%
'''
angle1 = np.linspace(0, 2*np.pi/3, segments)
angle2 = np.linspace(2*np.pi/3, 4*np.pi/3, segments)
angle3 = np.linspace(4*np.pi/3, 2*np.pi, segments)
r, R = 1.0, 2.0


#theta is the angle from center of donut to center of tube (corresponding to big radius, R)
#phi is the angle within the tube (corresponding to little radius, r)
theta, phi = np.meshgrid(angle1, angle1)
X1 = (R + r*np.cos(phi))*np.cos(theta)
Y1 = (R + r*np.cos(phi))*np.sin(theta)
Z1 = r*np.sin(phi)

theta, phi = np.meshgrid(angle1, angle2)
X2 = (R + r*np.cos(phi))*np.cos(theta)
Y2 = (R + r*np.cos(phi))*np.sin(theta)
Z2 = r*np.sin(phi)

theta, phi = np.meshgrid(angle1, angle3)
X3 = (R + r*np.cos(phi))*np.cos(theta)
Y3 = (R + r*np.cos(phi))*np.sin(theta)
Z3 = r*np.sin(phi)

theta, phi = np.meshgrid(angle2, angle1)
X4 = (R + r*np.cos(phi))*np.cos(theta)
Y4 = (R + r*np.cos(phi))*np.sin(theta)
Z4 = r*np.sin(phi)

theta, phi = np.meshgrid(angle2, angle2)
X5 = (R + r*np.cos(phi))*np.cos(theta)
Y5 = (R + r*np.cos(phi))*np.sin(theta)
Z5 = r*np.sin(phi)

theta, phi = np.meshgrid(angle2, angle3)
X6 = (R + r*np.cos(phi))*np.cos(theta)
Y6 = (R + r*np.cos(phi))*np.sin(theta)
Z6 = r*np.sin(phi)

theta, phi = np.meshgrid(angle3, angle1)
X7 = (R + r*np.cos(phi))*np.cos(theta)
Y7 = (R + r*np.cos(phi))*np.sin(theta)
Z7 = r*np.sin(phi)

theta, phi = np.meshgrid(angle3, angle2)
X8 = (R + r*np.cos(phi))*np.cos(theta)
Y8 = (R + r*np.cos(phi))*np.sin(theta)
Z8 = r*np.sin(phi)

theta, phi = np.meshgrid(angle3, angle3)
X9 = (R + r*np.cos(phi))*np.cos(theta)
Y9 = (R + r*np.cos(phi))*np.sin(theta)
Z9 = r*np.sin(phi)
'''



'''
#the higher the value of N the smoother the gradient
#my_colormap = LinearSegmentedColormap.from_list('my colormap', ['#00cc00', '#6300ba'], N = 50)
#we can add an alpha parameter to make the donut colour translucent
ax.plot_surface(X1, Y1, Z1, rstride = 1, cstride = 1, cmap = 'Reds')
ax.plot_surface(X2, Y2, Z2, rstride = 1, cstride = 1, cmap = 'Blues')
ax.plot_surface(X3, Y3, Z3, rstride = 1, cstride = 1, cmap = 'Greens')
ax.plot_surface(X4, Y4, Z4, rstride = 1, cstride = 1, cmap = 'Greens')
ax.plot_surface(X5, Y5, Z5, rstride = 1, cstride = 1, cmap = 'Reds')
ax.plot_surface(X6, Y6, Z6, rstride = 1, cstride = 1, cmap = 'Blues')
ax.plot_surface(X7, Y7, Z7, rstride = 1, cstride = 1, cmap = 'Blues')
ax.plot_surface(X8, Y8, Z8, rstride = 1, cstride = 1, cmap = 'Greens')
ax.plot_surface(X9, Y9, Z9, rstride = 1, cstride = 1, cmap = 'Reds')
'''

'''
even = 0
for i in range (0, len(X)):
    even += 1
    for j in range (0, len(X[i])):
        A, B = np.meshgrid(z_list, z_list)
        if (even%2 == 0):
            ax.scatter3D(X[i][j], Y[i][j], Z[i][j], c = 'orange')
        else:
            ax.scatter3D(X[i][j], Y[i][j], Z[i][j], c = 'purple')
'''
